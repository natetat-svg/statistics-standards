# %%
import sys
import pandas as pd
import numpy as np
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from src.data_loader import DataLoader

from src.data_loader import load_raw_data, validate_schema, inspect_data, EXPECTED_COLUMNS

# %%
# Load data
loader = DataLoader()
df = load_raw_data()
# Out:
# INFO | Loaded Steam_2024_bestRevenue_1500.csv -> 1500 rows x 11 columns

# %%
# 1. Basic Information
print("=" * 50)
print("DATASET OVERVIEW")
print("=" * 50)
print(f"Shape: {df.shape}")
print(f"\nColumn info:")
print(df.info())
# Out:
# ==================================================
# DATASET OVERVIEW
# ==================================================
# Shape: (1500, 11)
#
# Column info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1500 non-null   string
#  1   releaseDate     1500 non-null   datetime64[ns]
#  2   copiesSold      1500 non-null   Int64
#  3   price           1500 non-null   float64
#  4   revenue         1500 non-null   float64
#  5   avgPlaytime     1500 non-null   float64
#  6   reviewScore     1500 non-null   Int64
#  7   publisherClass  1500 non-null   category
#  8   publishers      1499 non-null   string
#  9   developers      1498 non-null   string
#  10  steamId         1500 non-null   Int64
# dtypes: Int64(3), category(1), datetime64[ns](1), float64(3), string(3)
# memory usage: 123.4 KB
# None

# %%
# 2. Sample Data
print("\nFirst 5 rows:")
print(df.head())
print(" ")
print('='*50)
print("\nLast 5 rows:")
print(df.tail())
# Out:
# First 5 rows:
#                               name releaseDate  copiesSold  price    revenue  \
# 0                         WWE 2K24  2024-03-07      165301  99.99  8055097.0
# 1            EARTH DEFENSE FORCE 6  2024-07-25      159806  59.99  7882151.0
# 2        Sins of a Solar Empire II  2024-08-15      214192  49.99  7815247.0
# 3                 Legend of Mortal  2024-06-14      440998  19.99  7756399.0
# 4  Shin Megami Tensei V: Vengeance  2024-06-13      141306  59.99  7629252.0
#
#    avgPlaytime  reviewScore publisherClass                   publishers  \
# 0    42.365140           71            AAA                           2K
# 1    29.651061           57          Indie                  D3PUBLISHER
# 2    12.452593           88          Indie       Stardock Entertainment
# 3    24.797817           76          Indie  Paras Games,Obb Studio Inc.
# 4    34.258496           96             AA                         SEGA
#
#                                           developers  steamId
# 0                                    Visual Concepts  2315690
# 1                                            SANDLOT  2291060
# 2  Ironclad Games Corporation,Stardock Entertainment  1575940
# 3                                    Obb Studio Inc.  1859910
# 4                                              ATLUS  1875830
#
# ==================================================
#
# Last 5 rows:
#                      name releaseDate  copiesSold  price    revenue  \
# 1495  Infection Free Zone  2024-04-11      452146  24.99  8739530.0
# 1496      Dark and Darker  2024-06-07     2640903   0.00  8706135.0
# 1497    Songs of Conquest  2024-05-20      501474  34.99  8641459.0
# 1498     GUNDAM BREAKER 4  2024-08-28      156339  59.99  8440898.0
# 1499               Peglin  2024-08-27      544144  19.99  8125042.0
#
#       avgPlaytime  reviewScore publisherClass  \
# 1495    14.494432           73          Indie
# 1496    31.974027           74          Indie
# 1497    11.891152           88             AA
# 1498    14.733899           81             AA
# 1499    30.160995           82          Indie
#
#                            publishers                 developers  steamId
# 1495                  Games Operators                Jutsu Games  1465460
# 1496                         IRONMACE                   IRONMACE  2016590
# 1497          Coffee Stain Publishing                 Lavapotion   867210
# 1498  Bandai Namco Entertainment Inc.  CRAFTS ＆ MEISTER Co., Ltd  1672500
# 1499    Red Nexus Games Inc.,IndieArk       Red Nexus Games Inc.  1296610

# %%
# 3. Statistical Summary
print("\nStatistical Summary:")
print(df.describe(include='all'))
# Out:
# Statistical Summary:
#             name                    releaseDate      copiesSold        price  \
# count       1500                           1500          1500.0  1500.000000
# unique      1500                            NaN            <NA>          NaN
# top     WWE 2K24                            NaN            <NA>          NaN
# freq           1                            NaN            <NA>          NaN
# mean         NaN  2024-05-04 21:23:31.199999744       141482.57    17.519513
# min          NaN            2024-01-01 00:00:00           593.0     0.000000
# 25%          NaN            2024-03-07 00:00:00         4918.75     9.990000
# 50%          NaN            2024-05-02 00:00:00         11928.5    14.990000
# 75%          NaN            2024-06-27 00:00:00        37869.75    19.990000
# max          NaN            2024-09-06 00:00:00      30739148.0    99.990000
# std          NaN                            NaN  1132756.660554    12.646612
#
#              revenue  avgPlaytime  reviewScore publisherClass    publishers  \
# count   1.500000e+03  1500.000000       1500.0           1500          1499
# unique           NaN          NaN         <NA>              4          1131
# top              NaN          NaN         <NA>          Indie  Kagura Games
# freq             NaN          NaN         <NA>           1301            17
# mean    2.632382e+06    12.562704    76.201333            NaN           NaN
# min     2.067400e+04     0.000000          0.0            NaN           NaN
# 25%     4.550425e+04     3.564848         72.0            NaN           NaN
# 50%     1.090530e+05     6.762776         83.0            NaN           NaN
# 75%     4.551568e+05    13.104473         92.0            NaN           NaN
# max     8.377934e+08   296.332852        100.0            NaN           NaN
# std     2.781024e+07    21.542173    24.319438            NaN           NaN
#
#             developers        steamId
# count             1498         1500.0
# unique            1406           <NA>
# top     Lust Desires 🖤           <NA>
# freq                 9           <NA>
# mean               NaN     2183788.46
# min                NaN        24880.0
# 25%                NaN      1792795.0
# 50%                NaN      2321985.0
# 75%                NaN      2693227.5
# max                NaN      3107330.0
# std                NaN  606772.455521

# %%
# 4. Missing Values
print("\nMissing Values:")
print(df.isnull().sum())
print(f"\nTotal missing: {df.isnull().sum().sum()}")
# Out:
# Missing Values:
# name              0
# releaseDate       0
# copiesSold        0
# price             0
# revenue           0
# avgPlaytime       0
# reviewScore       0
# publisherClass    0
# publishers        1
# developers        2
# steamId           0
# dtype: int64
#
# Total missing: 3

# %%
# 5. Data Types
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# name              string[python]
# releaseDate       datetime64[ns]
# copiesSold                 Int64
# price                    float64
# revenue                  float64
# avgPlaytime              float64
# reviewScore                Int64
# publisherClass          category
# publishers        string[python]
# developers        string[python]
# steamId                    Int64
# dtype: object

# %%
# 6. Unique Values for Categorical Columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    print(f"\nUnique values in {col}: {df[col].unique()}")
# Out:
# Unique values in publisherClass: ['AAA', 'Indie', 'AA', 'Hobbyist']
# Categories (4, object): ['AA', 'AAA', 'Hobbyist', 'Indie']

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# /home/natetat/Projects/statistics-standards/notebooks

# %%
# 7. Create data dictionary
dict_df = loader.create_data_dictionary(df)

from pathlib import Path
PROJECT_ROOT = Path.cwd().parent
reports_dir = PROJECT_ROOT / 'reports'
reports_dir.mkdir(parents=True, exist_ok=True)

dict_df.to_csv(reports_dir / 'data_dictionary.csv', index=False)
print("\nData dictionary created!")
# Out:
# Data dictionary created!
